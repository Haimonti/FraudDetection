# %%
import pandas as pd
import numpy as np
from MLP.utils import datasets,plot_table,train_model
from sklearn import metrics
from imblearn.under_sampling import RandomUnderSampler
from tabulate import tabulate
import matplotlib.pyplot as plt
from results.data_processing import DataProcessor
from results.utils import evaluate,null_check,results
from results.models import rus_boost, svm_model, xgb_model, logistic_regression_model, probit_regression_model,MLP
import json
from collections import defaultdict

# %%
data = pd.read_csv('data/data_FraudDetection_JAR2020.csv')
data_obj = DataProcessor(data,(1990,1999), (2000,2001), (2003,2014), 5)
with open('results/features.json') as json_file:
    features_comp = json.load(json_file)

# %%
import numpy as np
ben_data = pd.read_csv("Data/Beneish_scores_final.csv")
ben_data = ben_data.rename(columns={'Mistate':'misstate'})
ben_data = ben_data.replace([np.inf,-np.inf],np.nan)
ben_obj = DataProcessor(ben_data,(1990,1999), (2000,2001), (2003,2014), 5)
m_col = ['dsri','gmi','aqi','sgi','depi','sgai','lvgi','tata']
ben_items = {"Calculated M score Feat": m_col}

# %%
models = {"MLP": MLP,
         "RUS BOOST": rus_boost,
          "Logit":logistic_regression_model,
         "Probit":probit_regression_model}

# %% [markdown]
# ---

# %% [markdown]
# -----

# %% [markdown]
# ### Batch Processing

# %%
test_periods = [(2003,2005), (2003,2008), (2003,2011), (2003,2014)]

# %%
data_items = features_comp
train_period = (1990,1999)
res = defaultdict(lambda: defaultdict(dict))
for test_period in test_periods:
    for model in models.keys():
        for data_item in data_items.keys():
            auc = results(data_obj,train_period,test_period,data_items[data_item],models[model])
            res[test_period][data_item][model] = auc
        for ben_item in ben_items.keys():
            auc = results(ben_obj,train_period,test_period,ben_items[ben_item],models[model])
            res[test_period][ben_item][model] = auc
# Out:
# Training data Shape after sampling: (694, 42)
# Test data Shape: (17778, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (17778, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (17778, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (17906, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (17778, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (17778, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (17778, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (17906, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (17778, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (17778, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (17778, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (17906, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (17778, 42)
# Optimization terminated successfully.
#          Current function value: 0.539626
#          Iterations 10
# Training data Shape after sampling: (694, 28)
# Test data Shape: (17778, 28)
# Optimization terminated successfully.
#          Current function value: 0.602770
#          Iterations 9
# Training data Shape after sampling: (694, 14)
# Test data Shape: (17778, 14)
# Optimization terminated successfully.
#          Current function value: 0.619036
#          Iterations 6
# Training data Shape after sampling: (580, 8)
# Test data Shape: (17906, 8)
# Optimization terminated successfully.
#          Current function value: 0.682725
#          Iterations 8
# Training data Shape after sampling: (694, 42)
# Test data Shape: (35166, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (35166, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (35166, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (33993, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (35166, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (35166, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (35166, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (33993, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (35166, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (35166, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (35166, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (33993, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (35166, 42)
# Optimization terminated successfully.
#          Current function value: 0.539626
#          Iterations 10
# Training data Shape after sampling: (694, 28)
# Test data Shape: (35166, 28)
# Optimization terminated successfully.
#          Current function value: 0.602770
#          Iterations 9
# Training data Shape after sampling: (694, 14)
# Test data Shape: (35166, 14)
# Optimization terminated successfully.
#          Current function value: 0.619036
#          Iterations 6
# Training data Shape after sampling: (580, 8)
# Test data Shape: (33993, 8)
# Optimization terminated successfully.
#          Current function value: 0.682725
#          Iterations 8
# Training data Shape after sampling: (694, 42)
# Test data Shape: (51326, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (51326, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (51326, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (48620, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (51326, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (51326, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (51326, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (48620, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (51326, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (51326, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (51326, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (48620, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (51326, 42)
# Optimization terminated successfully.
#          Current function value: 0.539626
#          Iterations 10
# Training data Shape after sampling: (694, 28)
# Test data Shape: (51326, 28)
# Optimization terminated successfully.
#          Current function value: 0.602770
#          Iterations 9
# Training data Shape after sampling: (694, 14)
# Test data Shape: (51326, 14)
# Optimization terminated successfully.
#          Current function value: 0.619036
#          Iterations 6
# Training data Shape after sampling: (580, 8)
# Test data Shape: (48620, 8)
# Optimization terminated successfully.
#          Current function value: 0.682725
#          Iterations 8
# Training data Shape after sampling: (694, 42)
# Test data Shape: (68230, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (68230, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (68230, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (62848, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (68230, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (68230, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (68230, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (62848, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (68230, 42)
# Training data Shape after sampling: (694, 28)
# Test data Shape: (68230, 28)
# Training data Shape after sampling: (694, 14)
# Test data Shape: (68230, 14)
# Training data Shape after sampling: (580, 8)
# Test data Shape: (62848, 8)
# Training data Shape after sampling: (694, 42)
# Test data Shape: (68230, 42)
# Optimization terminated successfully.
#          Current function value: 0.539626
#          Iterations 10
# Training data Shape after sampling: (694, 28)
# Test data Shape: (68230, 28)
# Optimization terminated successfully.
#          Current function value: 0.602770
#          Iterations 9
# Training data Shape after sampling: (694, 14)
# Test data Shape: (68230, 14)
# Optimization terminated successfully.
#          Current function value: 0.619036
#          Iterations 6
# Training data Shape after sampling: (580, 8)
# Test data Shape: (62848, 8)
# Optimization terminated successfully.
#          Current function value: 0.682725
#          Iterations 8

# %%
for key in res.keys():
    columns = ["Test Period : "+str(key), 'MLP', 'RUS BOOST', 'Logit', 'Probit']
    df = pd.DataFrame.from_dict(res[key], orient='index').reset_index()
    df.columns = columns
    for col in ['MLP', 'RUS BOOST', 'Logit', 'Probit']:
        df[col] = df[col].round(3)
    df.set_index("Test Period : "+str(key), inplace=True)
    print(tabulate(df, headers='keys', tablefmt='pretty'))
# Out:
# +----------------------------------------------+-------+-----------+-------+--------+
# |          Test Period : (2003, 2005)          |  MLP  | RUS BOOST | Logit | Probit |
# +----------------------------------------------+-------+-----------+-------+--------+
# | 28 Raw Financial Items + 14 Financial Ratios | 0.647 |   0.695   | 0.596 | 0.609  |
# |            28 Raw Financial Items            | 0.64  |   0.686   | 0.526 | 0.529  |
# |             14 Financial Ratios              | 0.637 |   0.607   | 0.648 | 0.645  |
# |           Calculated M score Feat            |  0.5  |   0.586   | 0.537 | 0.562  |
# +----------------------------------------------+-------+-----------+-------+--------+
# +----------------------------------------------+-------+-----------+-------+--------+
# |          Test Period : (2003, 2008)          |  MLP  | RUS BOOST | Logit | Probit |
# +----------------------------------------------+-------+-----------+-------+--------+
# | 28 Raw Financial Items + 14 Financial Ratios | 0.634 |   0.702   | 0.599 | 0.611  |
# |            28 Raw Financial Items            | 0.638 |   0.687   | 0.528 | 0.528  |
# |             14 Financial Ratios              | 0.625 |   0.628   | 0.652 | 0.652  |
# |           Calculated M score Feat            |  0.5  |   0.584   | 0.544 |  0.56  |
# +----------------------------------------------+-------+-----------+-------+--------+
# +----------------------------------------------+-------+-----------+-------+--------+
# |          Test Period : (2003, 2011)          |  MLP  | RUS BOOST | Logit | Probit |
# +----------------------------------------------+-------+-----------+-------+--------+
# | 28 Raw Financial Items + 14 Financial Ratios | 0.631 |   0.706   | 0.615 | 0.626  |
# |            28 Raw Financial Items            | 0.631 |   0.69    | 0.55  | 0.552  |
# |             14 Financial Ratios              | 0.62  |   0.634   | 0.652 | 0.653  |
# |           Calculated M score Feat            |  0.5  |   0.587   | 0.544 | 0.567  |
# +----------------------------------------------+-------+-----------+-------+--------+
# +----------------------------------------------+-------+-----------+-------+--------+
# |          Test Period : (2003, 2014)          |  MLP  | RUS BOOST | Logit | Probit |
# +----------------------------------------------+-------+-----------+-------+--------+
# | 28 Raw Financial Items + 14 Financial Ratios | 0.626 |   0.706   | 0.619 | 0.627  |
# |            28 Raw Financial Items            | 0.626 |   0.683   | 0.546 | 0.546  |
# |             14 Financial Ratios              | 0.622 |   0.646   | 0.669 |  0.67  |
# |           Calculated M score Feat            |  0.5  |   0.583   | 0.547 | 0.566  |
# +----------------------------------------------+-------+-----------+-------+--------+

# %% [markdown]
# ----

# %% [markdown]
# ------

# %% [markdown]
# ## Window Processing

# %%
train_batches,test_batches = data_obj.create_batches()

# %%
for train_period,test_period in zip(train_batches[:-1],test_batches[:-1]):
    print(train_period,test_period)
# Out:
# (1990, 1995) (1996, 2001)
# (1996, 2001) (2002, 2006)
# (2002, 2006) (2007, 2011)
# (2007, 2011) (2012, 2016)
# (2012, 2016) (2017, 2021)

# %%
data_items = features_comp
res = defaultdict(lambda: defaultdict(dict))
for train_period,test_period in zip(train_batches[:-1],test_batches[:-1]):
    for model in models.keys():
        for data_item in data_items.keys():
            auc = results(data_obj,train_period,test_period,data_items[data_item],models[model])
            res[str(train_period) + '-' +str(test_period)][data_item][model] = auc
        for ben_item in ben_items.keys():
            auc = results(ben_obj,train_period,test_period,ben_items[ben_item],models[model])
            res[str(train_period) + '-' +str(test_period)][ben_item][model] = auc
# Out:
# Training data Shape after sampling: (286, 42)
# Test data Shape: (40192, 42)
# Training data Shape after sampling: (286, 28)
# Test data Shape: (40192, 28)
# Training data Shape after sampling: (286, 14)
# Test data Shape: (40192, 14)
# Training data Shape after sampling: (216, 8)
# Test data Shape: (42423, 8)
# Training data Shape after sampling: (286, 42)
# Test data Shape: (40192, 42)
# Training data Shape after sampling: (286, 28)
# Test data Shape: (40192, 28)
# Training data Shape after sampling: (286, 14)
# Test data Shape: (40192, 14)
# Training data Shape after sampling: (216, 8)
# Test data Shape: (42423, 8)
# Training data Shape after sampling: (286, 42)
# Test data Shape: (40192, 42)
# Training data Shape after sampling: (286, 28)
# Test data Shape: (40192, 28)
# Training data Shape after sampling: (286, 14)
# Test data Shape: (40192, 14)
# Training data Shape after sampling: (216, 8)
# Test data Shape: (42423, 8)
# Training data Shape after sampling: (286, 42)
# Test data Shape: (40192, 42)
# Optimization terminated successfully.
#          Current function value: 0.498506
#          Iterations 10
# Training data Shape after sampling: (286, 28)
# Test data Shape: (40192, 28)
# Optimization terminated successfully.
#          Current function value: 0.580061
#          Iterations 9
# Training data Shape after sampling: (286, 14)
# Test data Shape: (40192, 14)
# Optimization terminated successfully.
#          Current function value: 0.608704
#          Iterations 6
# Training data Shape after sampling: (216, 8)
# Test data Shape: (42423, 8)
# Optimization terminated successfully.
#          Current function value: 0.669697
#          Iterations 10
# Training data Shape after sampling: (742, 42)
# Test data Shape: (29753, 42)
# Training data Shape after sampling: (742, 28)
# Test data Shape: (29753, 28)
# Training data Shape after sampling: (742, 14)
# Test data Shape: (29753, 14)
# Training data Shape after sampling: (668, 8)
# Test data Shape: (29934, 8)
# Training data Shape after sampling: (742, 42)
# Test data Shape: (29753, 42)
# Training data Shape after sampling: (742, 28)
# Test data Shape: (29753, 28)
# Training data Shape after sampling: (742, 14)
# Test data Shape: (29753, 14)
# Training data Shape after sampling: (668, 8)
# Test data Shape: (29934, 8)
# Training data Shape after sampling: (742, 42)
# Test data Shape: (29753, 42)
# Training data Shape after sampling: (742, 28)
# Test data Shape: (29753, 28)
# Training data Shape after sampling: (742, 14)
# Test data Shape: (29753, 14)
# Training data Shape after sampling: (668, 8)
# Test data Shape: (29934, 8)
# Training data Shape after sampling: (742, 42)
# Test data Shape: (29753, 42)
# Optimization terminated successfully.
#          Current function value: 0.536646
#          Iterations 10
# Training data Shape after sampling: (742, 28)
# Test data Shape: (29753, 28)
# Optimization terminated successfully.
#          Current function value: 0.585333
#          Iterations 9
# Training data Shape after sampling: (742, 14)
# Test data Shape: (29753, 14)
# Optimization terminated successfully.
#          Current function value: 0.603220
#          Iterations 9
# Training data Shape after sampling: (668, 8)
# Test data Shape: (29934, 8)
# Optimization terminated successfully.
#          Current function value: 0.678238
#          Iterations 13
# Training data Shape after sampling: (564, 42)
# Test data Shape: (27640, 42)
# Training data Shape after sampling: (564, 28)
# Test data Shape: (27640, 28)
# Training data Shape after sampling: (564, 14)
# Test data Shape: (27640, 14)
# Training data Shape after sampling: (540, 8)
# Test data Shape: (25132, 8)
# Training data Shape after sampling: (564, 42)
# Test data Shape: (27640, 42)
# Training data Shape after sampling: (564, 28)
# Test data Shape: (27640, 28)
# Training data Shape after sampling: (564, 14)
# Test data Shape: (27640, 14)
# Training data Shape after sampling: (540, 8)
# Test data Shape: (25132, 8)
# Training data Shape after sampling: (564, 42)
# Test data Shape: (27640, 42)
# Training data Shape after sampling: (564, 28)
# Test data Shape: (27640, 28)
# Training data Shape after sampling: (564, 14)
# Test data Shape: (27640, 14)
# Training data Shape after sampling: (540, 8)
# Test data Shape: (25132, 8)
# Training data Shape after sampling: (564, 42)
# Test data Shape: (27640, 42)
# Optimization terminated successfully.
#          Current function value: 0.511275
#          Iterations 12
# Training data Shape after sampling: (564, 28)
# Test data Shape: (27640, 28)
# Optimization terminated successfully.
#          Current function value: 0.570099
#          Iterations 12
# Training data Shape after sampling: (564, 14)
# Test data Shape: (27640, 14)
# Optimization terminated successfully.
#          Current function value: 0.608295
#          Iterations 9
# Training data Shape after sampling: (540, 8)
# Test data Shape: (25132, 8)
# Optimization terminated successfully.
#          Current function value: 0.673887
#          Iterations 13
# Training data Shape after sampling: (268, 42)
# Test data Shape: (16904, 42)
# Training data Shape after sampling: (268, 28)
# Test data Shape: (16904, 28)
# Training data Shape after sampling: (268, 14)
# Test data Shape: (16904, 14)
# Training data Shape after sampling: (246, 8)
# Test data Shape: (23172, 8)
# Training data Shape after sampling: (268, 42)
# Test data Shape: (16904, 42)
# Training data Shape after sampling: (268, 28)
# Test data Shape: (16904, 28)
# Training data Shape after sampling: (268, 14)
# Test data Shape: (16904, 14)
# Training data Shape after sampling: (246, 8)
# Test data Shape: (23172, 8)
# Training data Shape after sampling: (268, 42)
# Test data Shape: (16904, 42)
# Training data Shape after sampling: (268, 28)
# Test data Shape: (16904, 28)
# Training data Shape after sampling: (268, 14)
# Test data Shape: (16904, 14)
# Training data Shape after sampling: (246, 8)
# Test data Shape: (23172, 8)
# Training data Shape after sampling: (268, 42)
# Test data Shape: (16904, 42)
# Optimization terminated successfully.
#          Current function value: 0.431732
#          Iterations 11
# Training data Shape after sampling: (268, 28)
# Test data Shape: (16904, 28)
# Optimization terminated successfully.
#          Current function value: 0.526644
#          Iterations 10
# Training data Shape after sampling: (268, 14)
# Test data Shape: (16904, 14)
# Optimization terminated successfully.
#          Current function value: 0.604956
#          Iterations 6
# Training data Shape after sampling: (246, 8)
# Test data Shape: (23172, 8)
# Optimization terminated successfully.
#          Current function value: 0.665317
#          Iterations 13
# Training data Shape after sampling: (68, 42)
# Test data Shape: (0, 42)
# Training data Shape after sampling: (68, 28)
# Test data Shape: (0, 28)
# Training data Shape after sampling: (68, 14)
# Test data Shape: (0, 14)
# Training data Shape after sampling: (92, 8)
# Test data Shape: (21212, 8)
# Training data Shape after sampling: (68, 42)
# Test data Shape: (0, 42)
# Training data Shape after sampling: (68, 28)
# Test data Shape: (0, 28)
# Training data Shape after sampling: (68, 14)
# Test data Shape: (0, 14)
# Training data Shape after sampling: (92, 8)
# Test data Shape: (21212, 8)
# Training data Shape after sampling: (68, 42)
# Test data Shape: (0, 42)
# Training data Shape after sampling: (68, 28)
# Test data Shape: (0, 28)
# Training data Shape after sampling: (68, 14)
# Test data Shape: (0, 14)
# Training data Shape after sampling: (92, 8)
# Test data Shape: (21212, 8)
# Training data Shape after sampling: (68, 42)
# Test data Shape: (0, 42)
# Training data Shape after sampling: (68, 28)
# Test data Shape: (0, 28)
# Training data Shape after sampling: (68, 14)
# Test data Shape: (0, 14)
# Training data Shape after sampling: (92, 8)
# Test data Shape: (21212, 8)
# Optimization terminated successfully.
#          Current function value: 0.619069
#          Iterations 11

# %%
res
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'(1990, 1995)-(1996, 2001)': defaultdict(dict,
#                          {'28 Raw Financial Items + 14 Financial Ratios': {'MLP': 0.5,
#                            'RUS BOOST': 0.7046322725463294,
#                            'Logit': 0.561341721183428,
#                            'Probit': 0.5767141516236642},
#                           '28 Raw Financial Items': {'MLP': 0.5,
#                            'RUS BOOST': 0.67387705534829,
#                            'Logit': 0.5481236078621643,
#                            'Probit': 0.5495846947434784},
#                           '14 Financial Ratios': {'MLP': 0.5,
#                            'RUS BOOST': 0.6482069931406658,
#                            'Logit': 0.635494579483079,
#                            'Probit': 0.6406290115923745},
#                           'Calculated M score Feat': {'MLP': 0.5,
#                            'RUS BOOST': 0.5224153607774116,
#                            'Logit': 0.5373400363614997,
#                            'Probit': 0.5387727716417292}}),
#              '(1996, 2001)-(2002, 2006)': defaultdict(dict,
#                          {'28 Raw Financial Items + 14 Financial Ratios': {'MLP': 0.6560891329401591,
#                            'RUS BOOST': 0.7499567431476692,
#                            'Logit': 0.6581208212617236,
#                            'Probit': 0.6845148410109132},
#                           '28 Raw Financial Items': {'MLP': 0.6556757562609331,
#                            'RUS BOOST': 0.776653139725529,
#                            'Logit': 0.6762258895690463,
#                            'Probit': 0.6806126999230642},
#                           '14 Financial Ratios': {'MLP': 0.5,
#                            'RUS BOOST': 0.6568507904512936,
#                            'Logit': 0.6601570819348556,
#                            'Probit': 0.6651062915316921},
#                           'Calculated M score Feat': {'MLP': 0.5,
#                            'RUS BOOST': 0.578881497462943,
#                            'Logit': 0.5752228664748892,
#                            'Probit': 0.5792571866634704}}),
#              '(2002, 2006)-(2007, 2011)': defaultdict(dict,
#                          {'28 Raw Financial Items + 14 Financial Ratios': {'MLP': 0.6380089662933786,
#                            'RUS BOOST': 0.6854056808229629,
#                            'Logit': 0.6183283213106285,
#                            'Probit': 0.628603148729558},
#                           '28 Raw Financial Items': {'MLP': 0.652330129328635,
#                            'RUS BOOST': 0.6786551862225989,
#                            'Logit': 0.5816502993648061,
#                            'Probit': 0.5801426228849933},
#                           '14 Financial Ratios': {'MLP': 0.62392275877936,
#                            'RUS BOOST': 0.6623051578434448,
#                            'Logit': 0.6837683175773861,
#                            'Probit': 0.6778084238879767},
#                           'Calculated M score Feat': {'MLP': 0.5,
#                            'RUS BOOST': 0.6471439387511553,
#                            'Logit': 0.5060038548724085,
#                            'Probit': 0.5056153768383219}}),
#              '(2007, 2011)-(2012, 2016)': defaultdict(dict,
#                          {'28 Raw Financial Items + 14 Financial Ratios': {'MLP': 0.603232330276509,
#                            'RUS BOOST': 0.7318089891558284,
#                            'Logit': 0.5586178039680603,
#                            'Probit': 0.6166288922207886},
#                           '28 Raw Financial Items': {'MLP': 0.5,
#                            'RUS BOOST': 0.7818909306461174,
#                            'Logit': 0.45505247742250426,
#                            'Probit': 0.4631001778304683},
#                           '14 Financial Ratios': {'MLP': 0.5,
#                            'RUS BOOST': 0.6798859792879808,
#                            'Logit': 0.7068987761079535,
#                            'Probit': 0.6760957495031208},
#                           'Calculated M score Feat': {'MLP': 0.5,
#                            'RUS BOOST': 0.6131993352108863,
#                            'Logit': 0.598660833468071,
#                            'Probit': 0.6090124422351654}}),
#              '(2012, 2016)-(2017, 2021)': defaultdict(dict,
#                          {'28 Raw Financial Items + 14 Financial Ratios': {'MLP': 'Done',
#                            'RUS BOOST': 'Done',
#                            'Logit': 'Done',
#                            'Probit': 'Done'},
#                           '28 Raw Financial Items': {'MLP': 'Done',
#                            'RUS BOOST': 'Done',
#                            'Logit': 'Done',
#                            'Probit': 'Done'},
#                           '14 Financial Ratios': {'MLP': 'Done',
#                            'RUS BOOST': 'Done',
#                            'Logit': 'Done',
#                            'Probit': 'Done'},
#                           'Calculated M score Feat': {'MLP': 0.5,
#                            'RUS BOOST': 0.48977115748145994,
#                            'Logit': 0.428051839464883,
#                            'Probit': 0.4310973171441035}})})

# %%
for key in res.keys():
    columns = ["Train - Test : "+str(key), 'MLP', 'RUS BOOST', 'Logit', 'Probit']
    df = pd.DataFrame.from_dict(res[key], orient='index').reset_index()
    df.columns = columns
    for col in ['MLP', 'RUS BOOST', 'Logit', 'Probit']:
         
        try:
            df[col] = df[col].round(3)
        except:
            pass
    df.set_index("Train - Test : "+str(key), inplace=True)
    print(tabulate(df, headers='keys', tablefmt='fancy_grid'))
# Out:
# ╒══════════════════════════════════════════════╤═══════╤═════════════╤═════════╤══════════╕
# │ Train - Test : (1990, 1995)-(1996, 2001)     │   MLP │   RUS BOOST │   Logit │   Probit │
# ╞══════════════════════════════════════════════╪═══════╪═════════════╪═════════╪══════════╡
# │ 28 Raw Financial Items + 14 Financial Ratios │   0.5 │       0.705 │   0.561 │    0.577 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 28 Raw Financial Items                       │   0.5 │       0.674 │   0.548 │    0.55  │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 14 Financial Ratios                          │   0.5 │       0.648 │   0.635 │    0.641 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ Calculated M score Feat                      │   0.5 │       0.522 │   0.537 │    0.539 │
# ╘══════════════════════════════════════════════╧═══════╧═════════════╧═════════╧══════════╛
# ╒══════════════════════════════════════════════╤═══════╤═════════════╤═════════╤══════════╕
# │ Train - Test : (1996, 2001)-(2002, 2006)     │   MLP │   RUS BOOST │   Logit │   Probit │
# ╞══════════════════════════════════════════════╪═══════╪═════════════╪═════════╪══════════╡
# │ 28 Raw Financial Items + 14 Financial Ratios │ 0.656 │       0.75  │   0.658 │    0.685 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 28 Raw Financial Items                       │ 0.656 │       0.777 │   0.676 │    0.681 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 14 Financial Ratios                          │ 0.5   │       0.657 │   0.66  │    0.665 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ Calculated M score Feat                      │ 0.5   │       0.579 │   0.575 │    0.579 │
# ╘══════════════════════════════════════════════╧═══════╧═════════════╧═════════╧══════════╛
# ╒══════════════════════════════════════════════╤═══════╤═════════════╤═════════╤══════════╕
# │ Train - Test : (2002, 2006)-(2007, 2011)     │   MLP │   RUS BOOST │   Logit │   Probit │
# ╞══════════════════════════════════════════════╪═══════╪═════════════╪═════════╪══════════╡
# │ 28 Raw Financial Items + 14 Financial Ratios │ 0.638 │       0.685 │   0.618 │    0.629 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 28 Raw Financial Items                       │ 0.652 │       0.679 │   0.582 │    0.58  │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 14 Financial Ratios                          │ 0.624 │       0.662 │   0.684 │    0.678 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ Calculated M score Feat                      │ 0.5   │       0.647 │   0.506 │    0.506 │
# ╘══════════════════════════════════════════════╧═══════╧═════════════╧═════════╧══════════╛
# ╒══════════════════════════════════════════════╤═══════╤═════════════╤═════════╤══════════╕
# │ Train - Test : (2007, 2011)-(2012, 2016)     │   MLP │   RUS BOOST │   Logit │   Probit │
# ╞══════════════════════════════════════════════╪═══════╪═════════════╪═════════╪══════════╡
# │ 28 Raw Financial Items + 14 Financial Ratios │ 0.603 │       0.732 │   0.559 │    0.617 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 28 Raw Financial Items                       │ 0.5   │       0.782 │   0.455 │    0.463 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ 14 Financial Ratios                          │ 0.5   │       0.68  │   0.707 │    0.676 │
# ├──────────────────────────────────────────────┼───────┼─────────────┼─────────┼──────────┤
# │ Calculated M score Feat                      │ 0.5   │       0.613 │   0.599 │    0.609 │
# ╘══════════════════════════════════════════════╧═══════╧═════════════╧═════════╧══════════╛
# ╒══════════════════════════════════════════════╤═══════╤═════════════════════╤═══════════════════╤════════════════════╕
# │ Train - Test : (2012, 2016)-(2017, 2021)     │ MLP   │ RUS BOOST           │ Logit             │ Probit             │
# ╞══════════════════════════════════════════════╪═══════╪═════════════════════╪═══════════════════╪════════════════════╡
# │ 28 Raw Financial Items + 14 Financial Ratios │ Done  │ Done                │ Done              │ Done               │
# ├──────────────────────────────────────────────┼───────┼─────────────────────┼───────────────────┼────────────────────┤
# │ 28 Raw Financial Items                       │ Done  │ Done                │ Done              │ Done               │
# ├──────────────────────────────────────────────┼───────┼─────────────────────┼───────────────────┼────────────────────┤
# │ 14 Financial Ratios                          │ Done  │ Done                │ Done              │ Done               │
# ├──────────────────────────────────────────────┼───────┼─────────────────────┼───────────────────┼────────────────────┤
# │ Calculated M score Feat                      │ 0.5   │ 0.48977115748145994 │ 0.428051839464883 │ 0.4310973171441035 │
# ╘══════════════════════════════════════════════╧═══════╧═════════════════════╧═══════════════════╧════════════════════╛
