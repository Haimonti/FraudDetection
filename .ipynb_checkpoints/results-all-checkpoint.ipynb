# %%
from results.data_processing import DataProcessor
from results.utils import evaluate,null_check,results
from results.models import rus_boost, svm_model, xgb_model, logistic_regression_model, probit_regression_model
import pandas as pd
import json

# %%
data = pd.read_csv('data/data_FraudDetection_JAR2020.csv')

# %%
data_obj = DataProcessor(data,(1991,1999), (2000,2001), (2003,2014), 5)

# %%
with open('results/features.json') as json_file:
    features_comp = json.load(json_file)

# %% [markdown]
# ## Bao RusBoost

# %%
test_periods = [(2003,2005), (2003,2008), (2003,2011), (2003,2014)]
models = {"RUS BOOST": rus_boost,
          "Logit":logistic_regression_model}
data_items = features_comp

# %%
train_period = (1991,1999)
for model in models.keys():
    print("MODEL: ", model)
    print("---"*25)
    for test_period in test_periods:
        print("Test period: ", test_period)
        print("---"*10)
        for data_item in data_items.keys():
            print(data_item)
            print("---"*5)
            print(results(data_obj,train_period,test_period,data_items[data_item],models[model]))
            print("---"*20)
        print("----"*20)
# Out:
# MODEL:  RUS BOOST
# ---------------------------------------------------------------------------
# Test period:  (2003, 2005)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (15724, 42)
# 0.6614186079575887
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (17778, 28)
# 0.709340631761371
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (15724, 14)
# 0.6156265398376074
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2008)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (30777, 42)
# 0.6559402496150948
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (35166, 28)
# 0.6851275026193153
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (30777, 14)
# 0.6301075113833655
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2011)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (44674, 42)
# 0.6653664205419599
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (51326, 28)
# 0.6738051627828321
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (44674, 14)
# 0.614433835122464
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2014)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (58405, 42)
# 0.6768616004836334
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (68230, 28)
# 0.6737258461957987
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (58405, 14)
# 0.6368783180306301
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# MODEL:  Logit
# ---------------------------------------------------------------------------
# Test period:  (2003, 2005)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (15724, 42)
# C:\Users\saite\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.5678999000870587
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (17778, 28)
# 0.6520753693904563
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (15724, 14)
# 0.6108498053353121
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2008)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (30777, 42)
# C:\Users\saite\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.5673432698922265
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (35166, 28)
# 0.6012622657777734
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (30777, 14)
# 0.6239855865299572
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2011)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (44674, 42)
# C:\Users\saite\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.5658260961568815
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (51326, 28)
# 0.5785436775977312
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (44674, 14)
# 0.6251586281539605
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2014)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 42)
# Test data Shape: (58405, 42)
# C:\Users\saite\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 0.5611472124682287
# ------------------------------------------------------------
# 28 Raw Financial Items
# ---------------
# Training data Shape after sampling: (664, 28)
# Test data Shape: (68230, 28)
# 0.5688908717160726
# ------------------------------------------------------------
# 14 Financial Ratios
# ---------------
# Training data Shape after sampling: (596, 14)
# Test data Shape: (58405, 14)
# 0.6376537315587756
# ------------------------------------------------------------
# --------------------------------------------------------------------------------

# %% [markdown]
# ------------

# %% [markdown]
# ## SVM -Beneish

# %%
import numpy as np
ben_data = pd.read_csv("Data/Beneish_scores_final.csv")
ben_data = ben_data.rename(columns={'Mistate':'misstate'})
ben_data = ben_data.replace([np.inf,-np.inf],np.nan)
ben_obj = DataProcessor(ben_data,(1991,1999), (2000,2001), (2003,2014), 5)

# %%
m_col = ['dsri','gmi','aqi','sgi','depi','sgai','lvgi','tata']

test_periods = [(2003,2005), (2003,2008), (2003,2011), (2003,2014)]
models = {"SVM": svm_model,
          "LOGIT":logistic_regression_model,
          "PROBIT": probit_regression_model}
data_items = {"Calculated M score Feat": m_col}

train_period = (1991,1999)
for model in models.keys():
    print("MODEL: ", model)
    print("---"*25)
    for test_period in test_periods:
        print("Test period: ", test_period)
        print("---"*10)
        for data_item in data_items.keys():
            print(data_item)
            print("---"*5)
            print(results(ben_obj,train_period,test_period,data_items[data_item],models[model]))
            print("---"*20)
        print("----"*20)
# Out:
# MODEL:  SVM
# ---------------------------------------------------------------------------
# Test period:  (2003, 2005)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (17602, 8)
# 0.5015771061535814
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2008)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (33425, 8)
# 0.5015824215571029
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2011)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (47800, 8)
# 0.5016321974643023
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2014)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (61765, 8)
# 0.501717905295382
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# MODEL:  LOGIT
# ---------------------------------------------------------------------------
# Test period:  (2003, 2005)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (17602, 8)
# 0.5754040954362111
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2008)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (33425, 8)
# 0.5899158180900682
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2011)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (47800, 8)
# 0.5832763107317198
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2014)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (61765, 8)
# 0.5855561720411934
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# MODEL:  PROBIT
# ---------------------------------------------------------------------------
# Test period:  (2003, 2005)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (17602, 8)
# Optimization terminated successfully.
#          Current function value: 0.674034
#          Iterations 11
# 0.5819440027388643
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2008)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (33425, 8)
# Optimization terminated successfully.
#          Current function value: 0.674034
#          Iterations 11
# 0.5995681034373793
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2011)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (47800, 8)
# Optimization terminated successfully.
#          Current function value: 0.674034
#          Iterations 11
# 0.5932842740274434
# ------------------------------------------------------------
# --------------------------------------------------------------------------------
# Test period:  (2003, 2014)
# ------------------------------
# Calculated M score Feat
# ---------------
# Training data Shape after sampling: (572, 8)
# Test data Shape: (61765, 8)
# Optimization terminated successfully.
#          Current function value: 0.674034
#          Iterations 11
# 0.594634363844329
# ------------------------------------------------------------
# --------------------------------------------------------------------------------

# %% [markdown]
# -------
# ------------

# %% [markdown]
# ## Window Processing

# %% [markdown]
# ## Bao RusBoost

# %%
tr_batches,test_batches = data_obj.create_batches()

# %%
tr_batches
# Out:
# [       fyear   gvkey  p_aaer  misstate      act       ap        at      ceq  \
#  4582    1991    1004     NaN         0  289.537   43.416   395.351  196.737
#  4583    1991    1009     NaN         0   12.911    6.549    35.559    6.538
#  4584    1991    1011     NaN         0    3.163    1.121     8.720    0.810
#  4585    1991    1013     NaN         0  119.530   10.167   247.169  158.374
#  4586    1991    1014     NaN         0    6.826    0.126    14.909   10.107
#  ...      ...     ...     ...       ...      ...      ...       ...      ...
#  38296   1996  220507     NaN         0  496.000  179.000  1430.000  710.000
#  38297   1996  220508     NaN         0  191.898    8.325   549.449  391.416
#  38298   1996  220748     NaN         0   79.753   12.913   103.795   75.641
#  38299   1996  223007     NaN         0  279.910   10.983   821.528  454.853
#  38300   1996  277918     NaN         0    3.440    2.868     4.363  -18.894
#
#            che     cogs  ...  soft_assets     ch_cs     ch_cm    ch_roa  issue  \
#  4582    4.197  331.056  ...     0.836553 -0.095484  0.155827 -0.012672      1
#  4583    0.048   27.072  ...     0.363340 -0.111586 -0.187708 -0.041154      1
#  4584    1.224    1.582  ...     0.350917  0.122455 -0.194342  0.067808      1
#  4585   30.109  134.160  ...     0.644304  0.148275  0.034543 -0.038006      1
#  4586    5.616    1.244  ...     0.245489  0.058214 -0.436089  0.115207      0
#  ...       ...      ...  ...          ...       ...       ...       ...    ...
#  38296  45.000  794.000  ...     0.399301       NaN       NaN       NaN      1
#  38297  52.071  580.924  ...     0.293680  0.659907 -0.038354  0.044648      1
#  38298  28.825   59.494  ...     0.644607       NaN       NaN       NaN      1
#  38299  83.785  299.836  ...     0.305195       NaN       NaN       NaN      1
#  38300   0.013    4.402  ...     0.805638 -0.600660 -2.658519  1.100372      1
#
#               bm       dpi       reoa      EBIT    ch_fcf
#  4582   0.961101  0.968053   0.259703  0.055586 -0.020650
#  4583   0.258828  0.859404   0.160184  0.105796 -0.023684
#  4584   0.151430  0.739250  -0.548968 -0.087615  0.139118
#  4585   0.483833  1.044093   0.541099  0.154582 -0.097427
#  4586   1.017569  0.635725   0.034610  0.257898 -0.198310
#  ...         ...       ...        ...       ...       ...
#  38296  0.614279  0.881869   0.158042  0.197902  0.014114
#  38297  0.334267  0.921859   0.312764  0.236198 -0.045887
#  38298  0.335513  0.309832  -0.064955  0.133976 -0.603349
#  38299  0.554051  0.804599   0.070474  0.055768 -0.180800
#  38300 -0.582081  1.281567 -17.646115 -1.710749  0.485527
#
#  [33719 rows x 46 columns],
#         fyear   gvkey  p_aaer  misstate       act       ap         at  \
#  31556   1996    1013     NaN         0   499.501   49.459    768.765
#  31557   1996    1019     NaN         0    10.364    2.532     28.968
#  31558   1996    1021     NaN         0    16.847    1.365     20.258
#  31559   1996    1034     NaN         0   274.859   30.557    613.407
#  31560   1996    1036     NaN         0   754.791  144.507   1618.265
#  ...      ...     ...     ...       ...       ...      ...        ...
#  71743   2001  233149     NaN         0    71.622   21.837    365.301
#  71744   2001  233397     NaN         0   371.861  158.127    957.460
#  71745   2001  241216     NaN         0  4320.000  687.000  10709.000
#  129136  0.009499      1  0.482145  1.178142 -0.191081  0.084592 -0.186510
#  129137 -0.292380      1  0.572661  1.199120  0.018127  0.166557 -0.417396
#  129138       NaN      1  1.866216  0.794896 -0.078596  0.039840 -0.000322
#  129139       NaN      1  0.322428       NaN -0.319651  0.076089       NaN
#  129140 -0.023106      1  1.127358  0.151757 -0.017284  0.019521 -0.146245
#
#  [33548 rows x 46 columns],
#          fyear   gvkey  p_aaer  misstate       act        ap         at  \
#  123737   2011    1004     NaN         0  1063.272   201.405   2195.653
#  123738   2011    1045     NaN         0  6757.000  1007.000  23848.000
#  123739   2011    1050     NaN         0    53.470     8.215     79.345
#  123740   2011    1072     NaN         0  1727.145   103.797   2468.012
#  123741   2011    1075     NaN         0   956.470   326.987  13111.018
#  ...       ...     ...     ...       ...       ...       ...        ...
#  146040   2014  314866     NaN         0   262.600    12.400   1234.800
#  146041   2014  315318     NaN         0  1578.400   106.700   4557.600
#  146042   2014  316056     NaN         0   973.800   249.500   2015.900
#  146043   2014  317260     NaN         0    51.743     1.555    322.421
#  146044   2014  317264     NaN         0   233.211     5.224   1099.101
#
#               ceq       che       cogs  ...  soft_assets     ch_cs     ch_cm  \
#  123737   864.649    67.720   1662.408  ...     0.761467  0.191150  0.545102
#  123738 -7111.000  4739.000  20420.000  ...     0.201401  0.074685 -0.161686
#  123739    42.990    12.724    100.066  ...     0.768416  0.038334  0.511236
#  123740  2120.753   813.417   1106.405  ...     0.574595 -0.036759 -0.016286
#  123741  3821.850    33.583   2067.817  ...     0.250610  0.001342  0.003850
#  ...          ...       ...        ...  ...          ...       ...       ...
#  146040   194.100   166.200    214.400  ...     0.751944  0.560406  0.127217
#  146041  2459.600   997.300    324.400  ...     0.742781 -0.118178  0.031360
#  146042    -4.800   290.500   1185.500  ...     0.751129  0.004207 -0.037925
#  146043   319.230    46.398     24.319  ...     0.018001       NaN       NaN
#  146044   873.214   204.821     43.338  ...     0.068841  1.684618 -0.094348
#
#            ch_roa  issue        bm       dpi      reoa      EBIT    ch_fcf
#  123737 -0.008841      1  1.781717  0.829860  0.221612  0.059652 -0.013265
#  123738 -0.062237      1 -7.034304  0.964431 -0.484317 -0.048348  0.072462
#  123739  0.079692      1  0.533614  1.159873 -0.013221  0.161573  0.082732
#  123740 -0.047812      1  0.943014  1.015906  0.752631  0.073181 -0.066825
#  123741 -0.002312      1  0.726108  1.011341  0.105432  0.058353 -0.019614
#  ...          ...    ...       ...       ...       ...       ...       ...
#  146040 -0.050591      1  0.103693  0.829680 -0.327178 -0.008179 -0.261606
#  146041  0.095355      1  0.581796  0.743084 -0.077826  0.000461 -0.296702
#  146042  0.072050      1 -0.000903  1.063878 -0.002877  0.153133  0.065569
#  146043       NaN      1  1.109467       NaN  0.000000  0.028804       NaN
#  146044  0.020573      1  1.154308  0.745399  0.025562  0.026433 -0.240183
#
#  [22308 rows x 46 columns]]

# %%
models = {"RUS BOOST": rus_boost,
          "Logit":logistic_regression_model}
data_items = features_comp

for (train_period,test_period) in zip(tr_batches,test_batches):
    print(train_period,test_period)
    for model in models.keys():
        print("MODEL: ", model)
        print("---"*25)
        for test_period in test_periods:
            print("Test period: ", test_period)
            print("---"*10)
            for data_item in data_items.keys():
                print(data_item)
                print("---"*5)
                print(results(data_obj,train_period,test_period,data_items[data_item],models[model]))
                print("---"*20)
            print("----"*20)
# Out:
#        fyear   gvkey  p_aaer  misstate      act       ap        at      ceq  \
# 4582    1991    1004     NaN         0  289.537   43.416   395.351  196.737
# 4583    1991    1009     NaN         0   12.911    6.549    35.559    6.538
# 4584    1991    1011     NaN         0    3.163    1.121     8.720    0.810
# 4585    1991    1013     NaN         0  119.530   10.167   247.169  158.374
# 4586    1991    1014     NaN         0    6.826    0.126    14.909   10.107
# ...      ...     ...     ...       ...      ...      ...       ...      ...
# 38296   1996  220507     NaN         0  496.000  179.000  1430.000  710.000
# 38297   1996  220508     NaN         0  191.898    8.325   549.449  391.416
# 38298   1996  220748     NaN         0   79.753   12.913   103.795   75.641
# 38299   1996  223007     NaN         0  279.910   10.983   821.528  454.853
# 38300   1996  277918     NaN         0    3.440    2.868     4.363  -18.894
#
#           che     cogs  ...  soft_assets     ch_cs     ch_cm    ch_roa  issue  \
# 4582    4.197  331.056  ...     0.836553 -0.095484  0.155827 -0.012672      1
# 4583    0.048   27.072  ...     0.363340 -0.111586 -0.187708 -0.041154      1
# 4584    1.224    1.582  ...     0.350917  0.122455 -0.194342  0.067808      1
# 4585   30.109  134.160  ...     0.644304  0.148275  0.034543 -0.038006      1
# 4586    5.616    1.244  ...     0.245489  0.058214 -0.436089  0.115207      0
# ...       ...      ...  ...          ...       ...       ...       ...    ...
# 38296  45.000  794.000  ...     0.399301       NaN       NaN       NaN      1
# 38297  52.071  580.924  ...     0.293680  0.659907 -0.038354  0.044648      1
# 38298  28.825   59.494  ...     0.644607       NaN       NaN       NaN      1
# 38299  83.785  299.836  ...     0.305195       NaN       NaN       NaN      1
# 38300   0.013    4.402  ...     0.805638 -0.600660 -2.658519  1.100372      1
#
#              bm       dpi       reoa      EBIT    ch_fcf
# 4582   0.961101  0.968053   0.259703  0.055586 -0.020650
# 4583   0.258828  0.859404   0.160184  0.105796 -0.023684
# 4584   0.151430  0.739250  -0.548968 -0.087615  0.139118
# 4585   0.483833  1.044093   0.541099  0.154582 -0.097427
# 4586   1.017569  0.635725   0.034610  0.257898 -0.198310
# ...         ...       ...        ...       ...       ...
# 38296  0.614279  0.881869   0.158042  0.197902  0.014114
# 38297  0.334267  0.921859   0.312764  0.236198 -0.045887
# 38298  0.335513  0.309832  -0.064955  0.133976 -0.603349
# 38299  0.554051  0.804599   0.070474  0.055768 -0.180800
# 38300 -0.582081  1.281567 -17.646115 -1.710749  0.485527
#
# [33719 rows x 46 columns]         fyear   gvkey  p_aaer  misstate       act       ap         at  \
# 77815    2003    1004     NaN         0   432.204   57.582    709.292
# 77816    2003    1013     NaN         0  1006.000   49.300   1296.900
# 77817    2003    1021     NaN         0     5.489    0.999      6.044
# 77818    2003    1034     NaN         0   692.991  122.780   2329.268
# 77819    2003    1038     NaN         0   435.736   87.497   1506.534
# ...       ...     ...     ...       ...       ...      ...        ...
# 112976   2008  282189     NaN         0   421.445  114.238   2049.931
# 112977   2008  284722     NaN         0    26.537    0.650     36.664
# 112978   2008  285660     NaN         0    81.647   14.246    136.142
# 112979   2008  287882     NaN         0  7122.172  183.775  22086.544
# 112980   2008  291721     NaN         0    29.110   14.442    104.344
#
#               ceq       che      cogs  ...  soft_assets     ch_cs     ch_cm  \
# 77815     301.684    41.010   523.302  ...     0.707952 -0.006354 -0.219484
# 77816     627.700   746.700   422.600  ...     0.275966 -0.349137  0.216712
# 77817       1.320     0.658    11.660  ...     0.816347 -0.100448  0.163097
# 77818    1131.989    58.623   729.995  ...     0.768092  0.013905 -0.217351
# 77819     280.404   333.248  1481.129  ...     0.262861 -0.017864 -0.019820
# ...           ...       ...       ...  ...          ...       ...       ...
# 112976    374.585   168.962   151.545  ...     0.151065  0.579066  0.033851
# 112977     34.597    24.304    18.621  ...     0.289057       NaN       NaN
# 112978     89.219    23.945    93.264  ...     0.535118  0.406126  0.309879
# 112979  15700.042  2659.198  7825.710  ...     0.548374  0.324091 -0.212662
# 112980     79.207    12.957    13.460  ...     0.154805       NaN       NaN
#
#           ch_roa  issue        bm       dpi      reoa      EBIT    ch_fcf
# 77815   0.022789      1  0.976617  1.012580  0.185938  0.028939  0.030194
# 77816   0.565607      1  0.302803  1.427923 -0.594649 -0.060529  1.291139
# 77817  -0.228271      1  0.837526  1.441992 -1.707148 -0.214593  0.193321
# 77818   0.048507      1  1.082328  0.904510  0.031126  0.033236  0.006734
# 77819   0.007507      1  0.495547  0.935015 -0.141191  0.051776  0.078478
# ...          ...    ...       ...       ...       ...       ...       ...
# 112976 -0.006522      1  0.373478  0.545030 -0.110769  0.070736  0.094369
# 112977       NaN      1  0.444742  0.674674 -0.836024 -0.290830 -0.031088
# 112978  0.040704      1  3.009682  1.175395  0.342796  0.208047 -0.179039
# 112979  0.113643      1  0.422339  1.106556  0.407016  0.329163 -0.065348
# 112980       NaN      0  1.162890  0.866322 -0.021410 -0.082774 -0.257666
#
# [35166 rows x 46 columns]
# MODEL:  RUS BOOST
# ---------------------------------------------------------------------------
# Test period:  (2003, 2005)
# ------------------------------
# 28 Raw Financial Items + 14 Financial Ratios
# ---------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [25], in <cell line: 6>()
#      15     print(data_item)
#      16     print("---"*5)
# ---> 17     print(results(data_obj,train_period,test_period,data_items[data_item],models[model]))
#      18     print("---"*20)
#      19 print("----"*20)
#
# File ~\Work\Masters\Summer23\Fraud detection\Fraud\Code\results\utils.py:30, in results(obj, train_period, test_period, item, model_name)
#      28 def results(obj, train_period, test_period, item, model_name):
#      29     # Split the data into training, validation, and test sets for the specified periods
# ---> 30     train_data, validation_data, test_data = obj.split_data_periods(train_period, test_period)
#      32     # Remove rows with missing values in the specified item from the datasets
#      33     train_data, validation_data, test_data = null_check(item, train_data, validation_data, test_data)
#
# File ~\Work\Masters\Summer23\Fraud detection\Fraud\Code\results\data_processing.py:32, in DataProcessor.split_data_periods(self, train_period, test_period)
#      19 def split_data_periods(self, train_period, test_period):
#      20     """
#      21     Split the data into training, validation, and test sets based on the specified periods.
#      22
#    (...)
#      30         test_data: DataFrame containing the test data.
#      31     """
# ---> 32     train_data = self.data[(self.data['fyear'] >= train_period[0]) & (self.data['fyear'] <= train_period[1])]
#      33     validation_data = self.data[(self.data['fyear'] >= self.val_period[0]) & (self.data['fyear'] <= self.val_period[1])]
#      34     test_data = self.data[(self.data['fyear'] >= test_period[0]) & (self.data['fyear'] <= test_period[1])]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 0
