# %% [markdown]
# ### Results
#
#
# | Neurons in HL   │   Learning Rate │ Activation Func   │   False Positive │   AUC-ROC │
# |:----------------|:---------------:|:-----------------:|:----------------:|
# │              90 │           0.001 │ relu              │            13481 │  0.605741 │
#
# │              90 │           0.001 │ logistic          │            11604 │  0.653701 │

# %%
import numpy as np
import pandas as pd```
import random
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from imblearn.under_sampling import RandomUnderSampler
from tabulate import tabulate
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# read the CSV file
df = pd.read_csv('data_FraudDetection_JAR2020.csv')

# %%
df.head(3)
# Out:
#    fyear  gvkey  p_aaer  misstate     act     ap       at     ceq    che  \
# 0   1990   1009     NaN         0  10.047  3.736   32.335   6.262  0.002
# 1   1990   1011     NaN         0   1.247  0.803    7.784   0.667  0.171
# 2   1990   1017     NaN         0  55.040  3.601  118.120  44.393  3.132
#
#       cogs  ...  soft_assets     ch_cs     ch_cm    ch_roa  issue        bm  \
# 0   30.633  ...     0.312448  0.095082  0.082631 -0.019761      1  0.413170
# 1    1.125  ...     0.315904  0.188832 -0.211389 -0.117832      1  0.157887
# 2  107.343  ...     0.605342  0.097551 -0.105780  0.091206      1  2.231337
#
#         dpi      reoa      EBIT    ch_fcf
# 0  0.873555  0.167620  0.161961 -0.042140
# 1  0.745139 -0.428957 -0.157888  0.100228
# 2  1.015131  0.394768  0.063681  0.066348
#
# [3 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['fyear', 'gvkey', 'p_aaer', 'misstate', 'act', 'ap', 'at', 'ceq', 'che',
#        'cogs', 'csho', 'dlc', 'dltis', 'dltt', 'dp', 'ib', 'invt', 'ivao',
#        'ivst', 'lct', 'lt', 'ni', 'ppegt', 'pstk', 're', 'rect', 'sale',
#        'sstk', 'txp', 'txt', 'xint', 'prcc_f', 'dch_wc', 'ch_rsst', 'dch_rec',
#        'dch_inv', 'soft_assets', 'ch_cs', 'ch_cm', 'ch_roa', 'issue', 'bm',
#        'dpi', 'reoa', 'EBIT', 'ch_fcf'],
#       dtype='object')

# %%
# select the columns to use as features
features = ['act', 'ap', 'at', 'ceq', 'che', 'cogs', 'csho', 'dlc', 'dltis', 'dltt', 'dp', 'ib', 'invt', 'ivao', 'ivst', 'lct', 'lt', 'ni', 'ppegt', 'pstk', 're', 'rect',
            'sale', 'sstk', 'txp', 'txt', 'xint', 'prcc_f', 'dch_wc', 'ch_rsst', 'dch_rec', 'dch_inv', 'soft_assets', 'ch_cs', 'ch_cm', 'ch_roa', 'bm', 'dpi', 'reoa', 'EBIT', 'ch_fcf']

raw_financial_items_28 = ['act', 'ap', 'at', 'ceq', 'che', 'cogs', 'csho', 'dlc', 'dltis', 'dltt', 'dp', 'ib', 'invt', 'ivao', 'ivst', 'lct', 'lt', 'ni', 'ppegt', 'pstk', 're', 'rect',
            'sale', 'sstk', 'txp', 'txt', 'xint', 'prcc_f']

financial_ratios_14 = ['dch_wc', 'ch_rsst', 'dch_rec', 'dch_inv', 'soft_assets', 'ch_cs', 'ch_cm', 'ch_roa', 'bm', 'dpi', 'reoa', 'EBIT', 'ch_fcf']

# %%
df[raw_financial_items_28].isna().sum()
# Out:
# act       0
# ap        0
# at        0
# ceq       0
# che       0
# cogs      0
# csho      0
# dlc       0
# dltis     0
# dltt      0
# dp        0
# ib        0
# invt      0
# ivao      0
# ivst      0
# lct       0
# lt        0
# ni        0
# ppegt     0
# pstk      0
# re        0
# rect      0
# sale      0
# sstk      0
# txp       0
# txt       0
# xint      0
# prcc_f    0
# dtype: int64

# %%
df[financial_ratios_14].isna().sum()
# Out:
# dch_wc          4759
# ch_rsst         4851
# dch_rec         4743
# dch_inv         4615
# soft_assets      592
# ch_cs          15918
# ch_cm          17107
# ch_roa         12678
# bm                18
# dpi             9228
# reoa             591
# EBIT             591
# ch_fcf          5407
# dtype: int64

# %%
df.shape
# Out:
# (146045, 46)

# %%
def train_model(X_train, y_train, X_test, y_test,inputs = 42,actv_func='relu', hidden_lay_neu=100,learning_rate=0.001):
    # Create model
    clf = MLPClassifier(hidden_layer_sizes=(inputs, hidden_lay_neu),
                        random_state=42,
                        verbose=False,
                        learning_rate_init=learning_rate,
                       activation=actv_func)

    # Fit data onto the model
    clf.fit(X_train, y_train)

    # Make prediction on test dataset
    ypred = clf.predict(X_test)
    auc = metrics.roc_auc_score(y_test, ypred)

    # Calculate the confusion matrix
    cm = confusion_matrix(y_test, ypred)
    TN, FP, FN, TP = cm[0, 0], cm[0, 1], cm[1, 0], cm[1, 1]  # True negatives ,False positives, False negatives, True positives
    
    
    return auc,(TN, FP, FN, TP)

# %% [markdown]
# ### Distinct Training and Testing Periods

# %%
data =  df.fillna(0)

# %%
train_data = data[(data['fyear'] >=1991 ) & (data['fyear'] <= 1999)]
validation_data = data[(data['fyear'] >= 2000 ) & (data['fyear'] <= 2001)]
test_data = data[(data['fyear'] >= 2003 ) & (data['fyear'] <= 2008)]

# %%
# Count positive and negative cases
train_misstate_1 = train_data['misstate'].value_counts()[1]
test_misstate_1 = test_data['misstate'].value_counts()[1]
train_misstate_0 = train_data['misstate'].value_counts()[0]
test_misstate_0 = test_data['misstate'].value_counts()[0]

# %%
print(f"Positives cases training: ", train_misstate_1)
print(f"Positives cases test: ", test_misstate_1)
print(f"Negative case training: ", train_misstate_0)
print(f"Negative case test: ", test_misstate_0)
# Out:
# Positives cases training:  332
# Positives cases test:  261
# Negative case training:  53720
# Negative case test:  34905

# %% [markdown]
# #### For all features

# %%
# Split the training and testing data into features and labels
X_train = train_data[features]
y_train = train_data['misstate']

X_test = test_data[features]
y_test = test_data['misstate']

# %%
rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

print(f"Number of observations in train set: {len(X_train_resampled)}")
# Out:
# Number of observations in train set: 664

# %%
y_train_resampled.value_counts()
# Out:
# 0    332
# 1    332
# Name: misstate, dtype: int64

# %%
print(train_model(X_train_resampled, y_train_resampled, X_test, y_test,inputs = 42,actv_func='relu', hidden_lay_neu=100,learning_rate=0.001))
# Out:
# (0.6172211272962573, (19417, 15488, 84, 177))

# %%
hidden_layer_neurons = [50,70,90,120,150]
learning_rates = [0.001,0.003,0.005,0.009,0.01]
actv_funs = ['relu','logistic','tanh']

# %%
def plot_graph(i,inp1,inp2):
    auc_list,fp_list,params = [],[],[]
    for i1 in inp1:
        for i2 in inp2:
            auc,(TN, FP, FN, TP) = train_model(X_train_resampled, y_train_resampled, X_test, y_test,inputs = 42,actv_func=i2, hidden_lay_neu=i,learning_rate=i1)
            auc_list.append(auc)
            fp_list.append(FP)
            params.append((i,i1,i2))
    return auc_list,fp_list,params

# %%
for neurons in hidden_layer_neurons:
    auc_list,fp_list,params = plot_graph(neurons,learning_rates,actv_funs)
    column1 = [x[0] for x in params]
    column2 = [x[1] for x in params]
    column3 = [x[2] for x in params]
    column4 = fp_list
    column5 = auc_list
    # column6 = fn_list

    #list of lists for the rows
    columns = list(zip(column1, column2, column3, column4, column5))

    #headers for each column
    headers = ['Neurons in HL', 'Learning Rate', 'Activation Func', 'False Positive', 'AUC-ROC']

    #table using the tabulate function
    table = tabulate(columns, headers, tablefmt="fancy_grid")

    print(table)
    
    param2_values = [param[1] for param in params]
    param3_values = [param[2] for param in params]

    # Plotting
    plt.plot(range(len(auc_list)), auc_list, marker='o')

    # Set x-axis ticks and labels
    plt.xticks(range(len(auc_list)), [f"{p2}, {p3}" for p2, p3 in zip(param2_values, param3_values)], rotation=45)

    # Set axis labels and title
    plt.xlabel('Parameters (LR, Act Func)')
    plt.ylabel('AUC Value')
    plt.title('AUC Values with Parameter Variations')

    # Show the plot
    plt.show()
# Out:
# ╒═════════════════╤═════════════════╤═══════════════════╤══════════════════╤═══════════╕
# │   Neurons in HL │   Learning Rate │ Activation Func   │   False Positive │   AUC-ROC │
# ╞═════════════════╪═════════════════╪═══════════════════╪══════════════════╪═══════════╡
# │              50 │           0.001 │ relu              │            12380 │  0.592776 │
# ├─────────────────┼─────────────────┼───────────────────┼──────────────────┼───────────┤
# │              50 │           0.001 │ logistic          │            11965 │  0.638951 │
# ├─────────────────┼─────────────────┼───────────────────┼──────────────────┼───────────┤
# │              50 │           0.001 │ tanh              │            13940 │  0.553189 │
# ├─────────────────┼─────────────────┼───────────────────┼──────────────────┼───────────┤
# │              50 │           0.003 │ relu              │            17730 │  0.619588 │
# ...

# %% [markdown]
# ### Considering 28 raw accounting data items only

# %%
# Split the training and testing data into features and labels
X_train = train_data[raw_financial_items_28]
y_train = train_data['misstate']

X_test = test_data[raw_financial_items_28]
y_test = test_data['misstate']

# %%
rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

print(f"Number of observations in train set: {len(X_train_resampled)}")
# Out:
# Number of observations in train set: 664

# %%
X_train_resampled.shape
# Out:
# (664, 28)

# %%
y_train_resampled.value_counts()
# Out:
# 0    332
# 1    332
# Name: misstate, dtype: int64

# %%
print(train_model(X_train_resampled, y_train_resampled, X_test, y_test,inputs = 42,actv_func='relu', hidden_lay_neu=100,learning_rate=0.001))
# Out:
# (0.6092388700364043, (21267, 13638, 102, 159))

# %%
hidden_layer_neurons = [50,70,90,120,150]
learning_rates = [0.001,0.003,0.005,0.009,0.01]
actv_funs = ['relu','logistic','tanh']

# %%
def plot_graph(i,inp1,inp2):
    auc_list,fp_list,params = [],[],[]
    for i1 in inp1:
        for i2 in inp2:
            auc,(TN, FP, FN, TP) = train_model(X_train_resampled, y_train_resampled, X_test, y_test,inputs = 28,actv_func=i2, hidden_lay_neu=i,learning_rate=i1)
            auc_list.append(auc)
            fp_list.append(FP)
            params.append((i,i1,i2))
    return auc_list,fp_list,params

# %%
for neurons in hidden_layer_neurons:
    auc_list,fp_list,params = plot_graph(neurons,learning_rates,actv_funs)
    column1 = [x[0] for x in params]
    column2 = [x[1] for x in params]
    column3 = [x[2] for x in params]
    column4 = fp_list
    column5 = auc_list
    # column6 = fn_list

    #list of lists for the rows
    columns = list(zip(column1, column2, column3, column4, column5))

    #headers for each column
    headers = ['Neurons in HL', 'Learning Rate', 'Activation Func', 'False Positive', 'AUC-ROC']

    #table using the tabulate function
    table = tabulate(columns, headers, tablefmt="fancy_grid")

    print(table)
    
    param2_values = [param[1] for param in params]
    param3_values = [param[2] for param in params]

    # Plotting
    plt.plot(range(len(auc_list)), auc_list, marker='o')

    # Set x-axis ticks and labels
    plt.xticks(range(len(auc_list)), [f"{p2}, {p3}" for p2, p3 in zip(param2_values, param3_values)], rotation=45)

    # Set axis labels and title
    plt.xlabel('Parameters (LR, Act Func)')
    plt.ylabel('AUC Value')
    plt.title('AUC Values with Parameter Variations')

    # Show the plot
    plt.show()
# Out:
# ╒═════════════════╤═════════════════╤═══════════════════╤══════════════════╤═══════════╕
# │   Neurons in HL │   Learning Rate │ Activation Func   │   False Positive │   AUC-ROC │
# ╞═════════════════╪═════════════════╪═══════════════════╪══════════════════╪═══════════╡
# │              50 │           0.001 │ relu              │             9444 │  0.571615 │
# ├─────────────────┼─────────────────┼───────────────────┼──────────────────┼───────────┤
# │              50 │           0.001 │ logistic          │            10254 │  0.623231 │
# ├─────────────────┼─────────────────┼───────────────────┼──────────────────┼───────────┤
# │              50 │           0.001 │ tanh              │            11974 │  0.640738 │
# ├─────────────────┼─────────────────┼───────────────────┼──────────────────┼───────────┤
# │              50 │           0.003 │ relu              │            13369 │  0.599682 │
# ...

# %% [markdown]
# ### For different testing periods

# %%
df = pd.read_csv('data_FraudDetection_JAR2020.csv')
data = df.fillna(0)   ## Only Financial ratios have null values

# %%
from MLP.utils import datasets, train_model,plot_table,plot_graph
import json

# %% [markdown]
# ##### 2003-2005

# %%
train_period, validation_period, test_period = (1991,1999), (2000,2001), (2003,2005)

train_data, val_data, test_data = datasets(data, train_period,validation_period,test_period)

with open('MLP/features.json') as json_file:
    data_feat = json.load(json_file)

raw_financial_items_28 = data_feat['raw_financial_items_28']

X_train, y_train = train_data[raw_financial_items_28], train_data['misstate']
X_test, y_test = test_data[raw_financial_items_28], test_data['misstate'] 

print("Training data Shape:", X_train.shape)
print("Testing data Shape:", X_test.shape)

rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

print("Training data Shape after sampling:", X_train_resampled.shape)
# Out:
# Training data Shape: (54052, 28)
# Testing data Shape: (17778, 28)
# Training data Shape after sampling: (664, 28)

# %%
hidden_layer_neurons = [50,70,90,120,150]
learning_rates = [0.001,0.003,0.005,0.009,0.01]
actv_funs = ['relu','logistic','tanh']

# %%
for neu in hidden_layer_neurons:
    plot_table(neu,learning_rates,actv_funs,X_train_resampled,y_train_resampled,X_test,y_test)
#     plot_graph(neu,learning_rates,actv_funs,X_train,y_train,X_test,y_test)
# Out:
# ╒═════════════════╤═════════════════╤═══════════════════╤═══════╤══════╤══════╤══════╤═══════════╕
# │   Neurons in HL │   Learning Rate │ Activation Func   │    TN │   FP │   FN │   TP │   AUC-ROC │
# ╞═════════════════╪═════════════════╪═══════════════════╪═══════╪══════╪══════╪══════╪═══════════╡
# │              50 │           0.001 │ relu              │ 13244 │ 4362 │  103 │   69 │  0.576703 │
# ├─────────────────┼─────────────────┼───────────────────┼───────┼──────┼──────┼──────┼───────────┤
# │              50 │           0.001 │ logistic          │ 12905 │ 4701 │   86 │   86 │  0.616494 │
# ├─────────────────┼─────────────────┼───────────────────┼───────┼──────┼──────┼──────┼───────────┤
# │              50 │           0.001 │ tanh              │ 11945 │ 5661 │   71 │  101 │  0.632836 │
# ├─────────────────┼─────────────────┼───────────────────┼───────┼──────┼──────┼──────┼───────────┤
# ...

# %%
train_period, validation_period, test_period = (1991,1999), (2000,2001), (2003,2011)

train_data, val_data, test_data = datasets(data, train_period,validation_period,test_period)

with open('MLP/features.json') as json_file:
    data_feat = json.load(json_file)

raw_financial_items_28 = data_feat['raw_financial_items_28']

X_train, y_train = train_data[raw_financial_items_28], train_data['misstate']
X_test, y_test = test_data[raw_financial_items_28], test_data['misstate'] 

print("Training data Shape:", X_train.shape)
print("Testing data Shape:", X_test.shape)

rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

print("Training data Shape after sampling:", X_train_resampled.shape)

hidden_layer_neurons = [50,70,90,120,150]
learning_rates = [0.001,0.003,0.005,0.009,0.01]
actv_funs = ['relu','logistic','tanh']

for neu in hidden_layer_neurons:
    plot_table(neu,learning_rates,actv_funs,X_train_resampled,y_train_resampled,X_test,y_test)
#     plot_graph(neu,learning_rates,actv_funs,X_train,y_train,X_test,y_test)
# Out:
# Training data Shape: (54052, 28)
# Testing data Shape: (51326, 28)
# Training data Shape after sampling: (664, 28)
# ╒═════════════════╤═════════════════╤═══════════════════╤═══════╤═══════╤══════╤══════╤═══════════╕
# │   Neurons in HL │   Learning Rate │ Activation Func   │    TN │    FP │   FN │   TP │   AUC-ROC │
# ╞═════════════════╪═════════════════╪═══════════════════╪═══════╪═══════╪══════╪══════╪═══════════╡
# │              50 │           0.001 │ relu              │ 36692 │ 14295 │  203 │  136 │  0.560407 │
# ├─────────────────┼─────────────────┼───────────────────┼───────┼───────┼──────┼──────┼───────────┤
# │              50 │           0.001 │ logistic          │ 35833 │ 15154 │  155 │  184 │  0.62278  │
# ├─────────────────┼─────────────────┼───────────────────┼───────┼───────┼──────┼──────┼───────────┤
# │              50 │           0.001 │ tanh              │ 33351 │ 17636 │  125 │  214 │  0.642688 │
# ...

# %%
train_period, validation_period, test_period = (1991,1999), (2000,2001), (2003,2014)

train_data, val_data, test_data = datasets(data, train_period,validation_period,test_period)

with open('MLP/features.json') as json_file:
    data_feat = json.load(json_file)

raw_financial_items_28 = data_feat['raw_financial_items_28']

X_train, y_train = train_data[raw_financial_items_28], train_data['misstate']
X_test, y_test = test_data[raw_financial_items_28], test_data['misstate'] 

print("Training data Shape:", X_train.shape)
print("Testing data Shape:", X_test.shape)

rus = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = rus.fit_resample(X_train, y_train)

print("Training data Shape after sampling:", X_train_resampled.shape)

hidden_layer_neurons = [50,70,90,120,150]
learning_rates = [0.001,0.003,0.005,0.009,0.01]
actv_funs = ['relu','logistic','tanh']

for neu in hidden_layer_neurons:
    plot_table(neu,learning_rates,actv_funs,X_train_resampled,y_train_resampled,X_test,y_test)
#     plot_graph(neu,learning_rates,actv_funs,X_train,y_train,X_test,y_test)
# Out:
# Training data Shape: (54052, 28)
# Testing data Shape: (68230, 28)
# Training data Shape after sampling: (664, 28)
# ╒═════════════════╤═════════════════╤═══════════════════╤═══════╤═══════╤══════╤══════╤═══════════╕
# │   Neurons in HL │   Learning Rate │ Activation Func   │    TN │    FP │   FN │   TP │   AUC-ROC │
# ╞═════════════════╪═════════════════╪═══════════════════╪═══════╪═══════╪══════╪══════╪═══════════╡
# │              50 │           0.001 │ relu              │ 48087 │ 19770 │  228 │  145 │  0.548696 │
# ├─────────────────┼─────────────────┼───────────────────┼───────┼───────┼──────┼──────┼───────────┤
# │              50 │           0.001 │ logistic          │ 47259 │ 20598 │  172 │  201 │  0.617662 │
# ├─────────────────┼─────────────────┼───────────────────┼───────┼───────┼──────┼──────┼───────────┤
# │              50 │           0.001 │ tanh              │ 44018 │ 23839 │  136 │  237 │  0.642038 │
# ...
